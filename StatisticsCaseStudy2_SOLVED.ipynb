# %% [markdown]
# #### Problem Statement 1:
#
# State whether each of the following situations is a correctly stated hypothesis testing problem and why.
#
# a. H0: μ = 25, H1: μ ≠ 25
#
# Correctly stated. The symbols are all correct and the hypotheses are mutually exclusive.
#
# b. H0: σ > 10, H1: σ = 10
#
# Not correctly stated. Hypothesis testing is not done with sigma (standard deviation).
#
# c. 𝐻0: 𝑥= 50, 𝐻1: 𝑥≠ 50
#
# Not correctly stated. is the actual mean of the samples collected and does not x have to do with hypothesis testing .
#
# d. H0: p = 0.1, H1: p = 0.5
#
# Not correctly stated. H0 and H1 are mutually exclusive, but rejecting H0 in this case does not necessarily mean H1 can be accepted.
#
# e. H0: s = 30, H1: s > 30
#
# Not correctly stated. Rejecting H0 does not necessarily mean H1 is accepted because of the values on the number line to the left of 30

# %%
import math
import scipy
import numpy as np
import pandas as pd
from scipy import stats

# %% [markdown]
# #### Problem Statement 2:
#
#
# The college bookstore tells prospective students that the average cost of its textbooks is Rs. 52 with a standard deviation of Rs. 4.50. A group of smart statistics students thinks that the average cost is higher. To test the bookstore’s claim against their alternative, the students will select a random sample of size 100. Assume that the mean from their random sample is Rs. 52.80. Perform a hypothesis test at the 5% level of significance and state your decision.

# %%
n = 100
x = 52.80
μ = 52
S  = 4.50

#State the hypotheses and significance level. The population mean is 100.
print('H0:μ=52\nHa:u≠52\nα = 0.05\n')

z = (x - μ) / (S/math.sqrt(n))
print('The Z-Score is {:.2f} :'.format(z))
pValue = scipy.stats.norm.cdf(z)
print('p-value associated with Z-Score {:.4f}'.format(pValue))
print('Probability of having values more than or equals to 52 is: {:.4f}'.format(1-pValue))
print('\nDecision: Reject Ho\ni.e. the average price is significantly more than Rs 52')
# Out:
# H0:μ=52
# Ha:u≠52
# α = 0.05
#
# The Z-Score is 1.78 :
# p-value associated with Z-Score 0.9623
# Probability of having values more than or equals to 52 is: 0.0377
#
# Decision: Reject Ho
# i.e. the average price is significantly more than Rs 52

# %% [markdown]
# #### Problem Statement 3:
#
# A certain chemical pollutant in the Genesee River has been constant for several years with mean μ = 34 ppm (parts per million) and standard deviation σ = 8 ppm. A group of factory representatives whose companies discharge liquids into the river is now claiming that they have lowered the average with improved filtration devices. A group of environmentalists will test to see if this is true at the 1% level of significance. Assume \that their sample of size 50 gives a mean of 32.5 ppm. Perform a hypothesis test at the 1% level of significance and state your decision.

# %%
n = 50
x = 32.5
μ = 34
S  = 8

#State the hypotheses and significance level. The population mean is 34.
print('H0:μ=34\nHa:u≠34\nα = 0.01\n')

z = (x - μ) / (S/math.sqrt(n))
print('The Z-Score is {:.2f} :'.format(z))
pValue = scipy.stats.norm.cdf(z)
print('p-value associated with Z-Score {:.4f}'.format(pValue))
print('Probability of having values more than or equals to 32.5 is: {:.4f}'.format(1-pValue))
print('\nDecision: Accept Ho\ni.e. the claim that they have lowered the average discharge is true.')
# Out:
# H0:μ=34
# Ha:u≠34
# α = 0.01
#
# The Z-Score is -1.33 :
# p-value associated with Z-Score 0.0924
# Probability of having values more than or equals to 32.5 is: 0.9076
#
# Decision: Accept Ho
# i.e. the claim that they have lowered the average discharge is true.

# %% [markdown]
# #### Problem Statement 4:
#
# Based on population figures and other general information on the U.S. population, suppose it has been estimated that, on average, a family of four in the U.S. spends about$1135 annually on dental expenditures. Suppose further that a regional dental association wants to test to determine if this figure is accurate for their area of country. To test this,22 families of 4 are randomly selected from the population in that area of the country and a log is kept of the family’s dental expenditure for one year. The resulting data are given below. Assuming, that dental expenditure is normally distributed in the population, use the data and an alpha of 0.5 to test the dental association’s hypothesis.
#
# 1008, 812, 1117, 1323, 1308, 1415, 831, 1021, 1287, 851, 930, 730, 699,872, 913, 944, 954, 987, 1695, 995, 1003, 994

# %%
pop = [1008, 812, 1117, 1323, 1308, 1415, 831, 1021, 
       1287, 851, 930, 730, 699,872, 913, 944, 954, 987, 1695, 995, 1003, 994]

pop =np.array(pop, dtype = float)

x = float('{:.2f}'.format(np.mean(pop)))
S = float('{:.2f}'.format(np.std(pop)))
n=22
μ = 1135
          
#State the hypotheses and significance level. The population mean is 34.
print('H0:μ=1135\nHa:u≠1135\nα = 0.05\n')

z = (x - μ) / (S/math.sqrt(n))
print('The Z-Score is {:.2f} :'.format(z))
pValue = scipy.stats.norm.cdf(z)
print('p-value associated with Z-Score {:.4f}'.format(pValue))
print('Probability of having values more than or equals to 1131 is: {:.4f}'.format(1-pValue))
print('\nDecision: Reject Ho\ni.e. the average dental expenses for the population is not accurate for their area.')
# Out:
# H0:μ=1135
# Ha:u≠1135
# α = 0.05
#
# The Z-Score is -2.07 :
# p-value associated with Z-Score 0.0192
# Probability of having values more than or equals to 1131 is: 0.9808
#
# Decision: Reject Ho
# i.e. the average dental expenses for the population is not accurate for their area.

# %% [markdown]
# #### Problem Statement 5:
#
# In a report prepared by the Economic Research Department of a major bank the Department manager maintains that the average annual family income on Metropolis is$48,432. What do you conclude about the validity of the report if a random sample of 400 families shows and average income of $48,574 with a standard deviation of 2000?

# %%
n = 400
x = 48574
μ = 48432
S  = 2000

#State the hypotheses and significance level. The population mean is 34.
print('H0:μ=48432\nHa:u≠48432\nα = 0.05\n')

z = (x - μ) / (S/math.sqrt(n))
print('The Z-Score is {:.2f} :'.format(z))
pValue = scipy.stats.norm.cdf(z)
print('p-value associated with Z-Score {:.4f}'.format(pValue))
print('Probability of having values more than or equals to 48574 is: {:.4f}'.format(1-pValue))
print('\nDecision: Accept Ho\ni.e. the average annual family income on Metropolis is48,432')
# Out:
# H0:μ=48432
# Ha:u≠48432
# α = 0.05
#
# The Z-Score is 1.42 :
# p-value associated with Z-Score 0.9222
# Probability of having values more than or equals to 48574 is: 0.0778
#
# Decision: Accept Ho
# i.e. the average annual family income on Metropolis is48,432

# %% [markdown]
# #### Problem Statement 6:
#
# Suppose that in past years the average price per square foot for warehouses in the United States has been $32.28. A national real estate investor wants to determine whether that figure has changed now. The investor hires a researcher who randomly samples 19 warehouses that are for sale across the United States and finds that the mean price per square foot is $31.67, with a standard deviation of $1.29. assume that the prices of warehouse footage are normally distributed in population. If the researcher uses a 5% level of significance, what statistical conclusion can be reached? What are the hypotheses?

# %%
n = 19
x = 31.67
μ = 32.28
S  = 1.29

#State the hypotheses and significance level. The population mean is 34.
print('H0:μ=32.28\nHa:u≠32.28\nα = 0.05\n')

z = (x - μ) / (S/math.sqrt(n))
print('The Z-Score is {:.2f} :'.format(z))
pValue = scipy.stats.norm.cdf(z)
print('p-value associated with Z-Score {:.4f}'.format(pValue))
print('Probability of having values more than or equals to 31.67 is: {:.4f}'.format(1-pValue))
print('\nDecision: Reject Ho\ni.e. the average price per square foot for warehouses has changed now')
# Out:
# H0:μ=32.28
# Ha:u≠32.28
# α = 0.05
#
# The Z-Score is -2.06 :
# p-value associated with Z-Score 0.0196
# Probability of having values more than or equals to 31.67 is: 0.9804
#
# Decision: Reject Ho
# i.e. the average price per square foot for warehouses has changed now

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('α = P(type I error)')
print('α = P1(X<48.5;μ = 50)+ P1(X>51.5; μ=50)')
#print('α = 2 x P1(X<48.5)')

S= 2.5
n = 10
X1 = 48.5
X2 = 51.5
μ = 50

Z1 = (X1- μ)/(S/math.sqrt(n))
Z2 = (X2- μ)/(S/math.sqrt(n))
print('Z1 =' , Z1)
print('Z2 =' , Z2)
print('α1  = {:.4f}'.format(2*scipy.stats.norm.cdf(Z1)))

X3 = 48
X4 = 52
μ = 50

#reduce α by  widening  the  acceptanceregion; make the critical values 48 and 52
Z3 = (X3- μ)/(S/math.sqrt(n))
Z4 = (X4- μ)/(S/math.sqrt(n))
print('Z3 =' , Z3)
print('Z4 =' , Z4)
print('α2  = {:.4f}'.format(2*scipy.stats.norm.cdf(Z3)))

#reduce α by increasing the sample size; make n = 16
X5 = 48.81
X6 = 51.9
n = 16
Z5 = (X5- μ)/(S/math.sqrt(n))
Z6 = (X6- μ)/(S/math.sqrt(n))
print('Z5 =' , Z5)
print('Z6 =' , Z6)
print('α3  = {:.4f}'.format(-scipy.stats.norm.cdf(Z5)+scipy.stats.norm.cdf(Z6)))


X7 = 48.42
X8 = 51.58
Z7 = (X7- μ)/(S/math.sqrt(n))
Z8 = (X8- μ)/(S/math.sqrt(n))
print('Z7 =' , Z7)
print('Z8 =' , Z8)
print('α4  = {:.4f}'.format(-scipy.stats.norm.cdf(Z7)+ scipy.stats.norm.cdf(Z8)))

print('β=P(type II error)')
μ = 52
n =10

print('β=P(48.5≤X≤51.5;μ=52)')
Za = (X1- μ)/(S/math.sqrt(n))
Zb = (X2- μ)/(S/math.sqrt(n))
βza  = float('{:.4f}'.format(scipy.stats.norm.cdf(Za)))
βzb  = float('{:.4f}'.format(scipy.stats.norm.cdf(Zb)))
print('β1(μ = 52)  =', βzb -βza)

μ=50.5
n =10

Zaa = (X1- μ)/(S/math.sqrt(n))
Zbb = (X2- μ)/(S/math.sqrt(n))
βzaa  = float('{:.4f}'.format(scipy.stats.norm.cdf(Zaa)))
βzbb  = float('{:.4f}'.format(scipy.stats.norm.cdf(Zbb)))
print('β1(μ = 50.5)  =', βzbb -βzaa)

μ = 52
n =10

Zc = (X3- μ)/(S/math.sqrt(n))
Zd = (X4- μ)/(S/math.sqrt(n))
βzc  = float('{:.4f}'.format(scipy.stats.norm.cdf(Zc)))
βzd  = float('{:.4f}'.format(scipy.stats.norm.cdf(Zd)))
print('β2(μ = 52)  =', βzd -βzc)

μ=50.5
n =10
Zcc = (X3- μ)/(S/math.sqrt(n))
Zdd = (X4- μ)/(S/math.sqrt(n))
βzcc  = float('{:.4f}'.format(scipy.stats.norm.cdf(Zcc)))
βzdd  = float('{:.4f}'.format(scipy.stats.norm.cdf(Zdd)))
print('β2(μ = 50.5)  ={:.4f}'.format(βzdd -βzcc))

μ = 52
n =16

Ze = (X5- μ)/(S/math.sqrt(n))
Zf = (X6- μ)/(S/math.sqrt(n))
βze  = float('{:.4f}'.format(scipy.stats.norm.cdf(Ze)))
βzf  = float('{:.4f}'.format(scipy.stats.norm.cdf(Zf)))
print('β3(μ = 52)  ={:.4f}'.format(βzf -βze))

μ=50.5
n =16
Zee = (X5- μ)/(S/math.sqrt(n))
Zff = (X6- μ)/(S/math.sqrt(n))
βzee  = float('{:.4f}'.format(scipy.stats.norm.cdf(Zee)))
βzff  = float('{:.4f}'.format(scipy.stats.norm.cdf(Zff)))
print('β3(μ = 50.5)  ={:.4f}'.format(βzff -βzee))

μ = 52
n =16

Zg = (X7- μ)/(S/math.sqrt(n))
Zh = (X8- μ)/(S/math.sqrt(n))
βzg  = float('{:.4f}'.format(scipy.stats.norm.cdf(Zg)))
βzh  = float('{:.4f}'.format(scipy.stats.norm.cdf(Zh)))
print('β4(μ = 52)  ={:.4f}'.format(βzh -βzg))

μ=50.5
n =16
Zgg = (X5- μ)/(S/math.sqrt(n))
Zhh = (X6- μ)/(S/math.sqrt(n))
βzgg  = float('{:.4f}'.format(scipy.stats.norm.cdf(Zgg)))
βzhh  = float('{:.4f}'.format(scipy.stats.norm.cdf(Zhh)))
print('β4(μ = 50.5)  ={:.4f}'.format(βzhh -βzgg))
# Out:
# α = P(type I error)
# α = P1(X<48.5;μ = 50)+ P1(X>51.5; μ=50)
# Z1 = -1.8973665961010278
# Z2 = 1.8973665961010278
# α1  = 0.0578
# Z3 = -2.5298221281347035
# Z4 = 2.5298221281347035
# α2  = 0.0114
# Z5 = -1.9039999999999964
# Z6 = 3.039999999999998
# α3  = 0.9704
# Z7 = -2.5279999999999974
# Z8 = 2.5279999999999974
# α4  = 0.9885
# β=P(type II error)
# β=P(48.5≤X≤51.5;μ=52)
# β1(μ = 52)  = 0.2635
# β1(μ = 50.5)  = 0.8913
# β2(μ = 52)  = 0.5
# β2(μ = 50.5)  =0.9703
# β3(μ = 52)  =0.4364
# β3(μ = 50.5)  =0.9841
# β4(μ = 52)  =0.2508
# β4(μ = 50.5)  =0.9841

# %% [markdown]
# When the null hypothesis is false,β increases as the true value of the parameter approaches the value hypothesized in the null hypothesis
#
# The size of the critical region, and consequently the probability of a typeI errorα, can always be reduced by appropriate selection of the criticalvalues
#
# Type I and type II errors are related. When sample sizenis fixed, a de-crease in the probability of one type of error always results in an increasein the probability of the other.
#
# An increase in sample size will generally reduce both α and β, provided that the critical values are held constant.

# %% [markdown]
# Acceptance region	Sample Size	α	β at μ=52	β at μ=50.5
# 48.5≤ ̄X≤51.5	10	0.0578	0.2635	0.9445
# 48≤ ̄X≤52	10	0.0114	0.5	0.9703
# 48.81≤ ̄X≤51.9	16	0.9704	0.4364	0.9841
# 48.42≤ ̄X≤51.58	16	0.9885	0.2508	0.9841
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem Statement 8:
#
# Find the t-score for a sample size of 16 taken from a population with mean 10 when the sample mean is 12 and the sample standard deviation is 1.5.

# %% [markdown]
# ![image.png](attachment:image.png)t

# %%
u = 10
X = 12
S = 1.5
n =16

t = (X-u)/(S/math.sqrt(n))
print('t-score is: {:4f}'.format(t))
# Out:
# t-score is: 5.333333

# %% [markdown]
# #### Problem Statement 9:
#
# Find the t-score below which we can expect 99% of sample means will fall if samples of size 16 are taken from a normally distributed population.

# %%
# n = 16, degree of freedom = 16-1 = 8
# for 99% confidence interval, alpha = 1% = 0.01 and alpha/2 = 0.005
ci = 0.99
n = 16
t = stats.t.ppf(1- ((1-ci)), n-1) 
print('{:.4f}'.format(t))
# Out:
# 2.6025

# %% [markdown]
# #### Problem Statement 10:
#
# If a random sample of size 25 drawn from a normal population gives a mean of 60 and a standard deviation of 4, find the range of t-scores where we can expect to find the middle 95% of all sample means. Compute the probability that (−𝑡0.05 <𝑡<𝑡0.10).

# %%
n = 25
ci = 0.95
X = 60
S = 4
#u =?
t = (X-u)/(S/math.sqrt(n))
t0 = float('{:.4f}'.format(stats.t.ppf(1-ci, n-1 )))
t1 = float('{:.4f}'.format(stats.t.ppf(0.1, n-1 )))
print(t0,t1)
float('{:.4f}'.format(scipy.stats.norm.cdf(t0)))
float('{:.4f}'.format(scipy.stats.norm.cdf(t1)))
pValue = float('{:.4f}'.format(scipy.stats.norm.cdf(t1)))-float('{:.4f}'.format(scipy.stats.norm.cdf(t0)))
print(pValue)
# Out:
# -1.7109 -1.3178
# 0.0503

# %% [markdown]
# #### Problem Statement 11:
#
# Two-tailed test for difference between two population meansIs there evidence to conclude that the number of people travelling from Bangalore to Chennai is different from the number of people travelling from Bangalore to Hosur in a week, given the following:Population
#
# 1: Bangalore to Chennai
#
# n1 = 1200
#
# x1 = 452
#
# s1= 212
#
# Population
#
# 2: Bangalore to Hosur
#
# n2 = 800
#
# x2 = 523
#
# s2 = 185

# %%
print('H0:μ1=μ2\nHa:μ1≠μ2\nα = 0.05\n')
#Bangalore to Chennai 
n1 = 1200
x1 = 452
s1= 212

#Bangalore to Hosur
n2 = 800
x2 = 523
s2 = 185


x = x1-x2; 
print('x1-x2 =', x) 

se = float('{:.4f}'.format(math.sqrt(s1**2/n1 +s2**2/n2)))
print('se =',se)
z = float('{:.4f}'.format(x/se))
print('z=', z)
print('\np≈P(|Z|≥z)')
p = float('{:.4f}'.format(scipy.stats.norm.cdf(z)))
display(p)
print('With 95% confidence, the difference in population means is between {} and {}'.format(x-se, x+se))
print('\nDecision: Reject Ho\ni.e. there is no evidence to conclude that the number of people travelling from \
Bangalore to Chennai is the same as that of people travelling from Bangalore to Hosur in a week')
# Out:
# H0:μ1=μ2
# Ha:μ1≠μ2
# α = 0.05
#
# x1-x2 = -71
# se = 8.9574
# z= -7.9264
#
# p≈P(|Z|≥z)
# 0.0
# With 95% confidence, the difference in population means is between -79.9574 and -62.0426
#
# Decision: Reject Ho
# i.e. there is no evidence to conclude that the number of people travelling from Bangalore to Chennai is the same as that of people travelling from Bangalore to Hosur in a week

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Duracell
n1 = 100
x1 = 308
s1 = 84

#Energizer
n2 = 100
x2 = 254
s2 = 67

#u= μ1-μ2 
u= 45 

Z = ((x1-x2)-u)/math.sqrt(s1**2/n1 +s2**2/n2)
p = float('{:.4f}'.format(scipy.stats.norm.cdf(Z)))
print('p(Z<0.84) is ',p)
print('The difference in the average lives of Duracell and Energizer \
batteries based on samples does not exceed 54 minutes')
# Out:
# p(Z<0.84) is  0.7989
# The difference in the average lives of Duracell and Energizer batteries based on samples does not exceed 54 minutes

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Population 1
n1 = 14
x1 = 0.317
s1 = 0.12
u1 = 27.50

#Population 2
n2 = 9
x2 = 0.21
s2 = 0.11
u2 = 20.00

u= 27.50-20.00 

Z = ((x1-x2)-u)/math.sqrt(s1**2/n1 +s2**2/n2); display(Z)
p = float('{:.4f}'.format(scipy.stats.norm.cdf(Z)))
print('p(Z) is ',p)
print('The data does not provide sufficient evidence to conclude that average percentage \
increase in the price of sugar differs when it is sold at two different prices')
# Out:
# -151.76456610514725
# p(Z) is  0.0
# The data does not provide sufficient evidence to conclude that average percentage increase in the price of sugar differs when it is sold at two different prices

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Men = [2792,1486]
Women = [3591, 2131]
Observed_values = np.array([Men, Women]);display(Observed_values)

chi2, p, ddof, Expected_values = stats.chi2_contingency(Observed_values); display(Expected_values)

test_statistic = "Test Statistic: {}\np-value: {}\nDegrees of Freedom: {}\n"
print(test_statistic.format(chi2, p, ddof))

print('\nHo: gender and voting independent')
print('\nHa: gender and voting are dependent')
print('\nα = 0.01')
print('Decision: Accept Ho')
# Out:
# array([[2792, 1486],
#        [3591, 2131]])
# array([[2730.6474, 1547.3526],
#        [3652.3526, 2069.6474]])
# Test Statistic: 6.552337973968181
# p-value: 0.01047464310091866
# Degrees of Freedom: 1
#
#
# Ho: gender and voting independent
#
# Ha: gender and voting are dependent
#
# α = 0.01
# Decision: Accept Ho

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
H = [41]
R = [19]
W = [24]
C = [16]

Observed_values = np.array([H, R, W, C]);display(Observed_values)

chi2, p, ddof, Expected_values = stats.chi2_contingency(Observed_values); display(Expected_values)

test_statistic = "Test Statistic: {}\np-value: {}\nDegrees of Freedom: {}\n"
print(test_statistic.format(chi2, p, ddof))

print('\nHo: all candidates are equally popular')
print('\nHa: all candidates are not equally popular')
print('\nα = 0.05')
print('Decision: Reject Ho')
# Out:
# array([[41],
#        [19],
#        [24],
#        [16]])
# array([[41.],
#        [19.],
#        [24.],
#        [16.]])
# Test Statistic: 0.0
# p-value: 1.0
# Degrees of Freedom: 0
#
#
# Ho: all candidates are equally popular
#
# Ha: all candidates are not equally popular
#
# α = 0.05
# Decision: Reject Ho

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = [18, 2, 20]
B = [22, 28, 10] #W_D_S = widowed, divorced or seperated
C =[20, 40, 40]
Observed_values = np.array([A, B, C]);display(Observed_values)

chi2, p, ddof, Expected_values = stats.chi2_contingency(Observed_values); display(Expected_values)

test_statistic = "Test Statistic: {}\np-value: {}\nDegrees of Freedom: {}\n"
print(test_statistic.format(chi2, p, ddof))

print('\nHo: There is a significant relationship between age and photograph preference')
print('\nHa: There is no significant relationship between age and photograph preference')
print('\nα = 0.05')
print('Decision: Reject Ho')
# Out:
# array([[18,  2, 20],
#        [22, 28, 10],
#        [20, 40, 40]])
# array([[12., 14., 14.],
#        [18., 21., 21.],
#        [30., 35., 35.]])
# Test Statistic: 29.603174603174605
# p-value: 5.894582174262628e-06
# Degrees of Freedom: 4
#
#
# Ho: There is a significant relationship between age and photograph preference
#
# Ha: There is no significant relationship between age and photograph preference
#
# α = 0.05
# Decision: Reject Ho

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Support = [18,32]
No_Support = [40,10]
Observed_values = np.array([Support,No_Support]);display(Observed_values)

chi2, p, ddof, Expected_values = stats.chi2_contingency(Observed_values); display(Expected_values)

test_statistic = "Test Statistic: {}\np-value: {}\nDegrees of Freedom: {}\n"
print(test_statistic.format(chi2, p, ddof))

print('\nHo: There a significant difference between the "support" and "no support" ')
print('\nHa: There no significant difference between the "support" and "no support" ')
print('\nα = 0.05')
print('Decision: Reject Ho')
# Out:
# array([[18, 32],
#        [40, 10]])
# array([[29., 21.],
#        [29., 21.]])
# Test Statistic: 18.10344827586207
# p-value: 2.092221924065813e-05
# Degrees of Freedom: 1
#
#
# Ho: There a significant difference between the "support" and "no support"
#
# Ha: There no significant difference between the "support" and "no support"
#
# α = 0.05
# Decision: Reject Ho

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Short = [12, 22,9]
Tall = [32, 14, 6]
Observed_values = np.array([Short,Tall]);display(Observed_values)

chi2, p, ddof, Expected_values = stats.chi2_contingency(Observed_values); display(Expected_values)

test_statistic = "Test Statistic: {}\np-value: {}\nDegrees of Freedom: {}\n"
print(test_statistic.format(chi2, p, ddof))

print('\nHo: There is a relationsip between height and leadership qualities')
print('\nHa: There is no relationsip between height and leadership qualities')
print('\nα = 0.01')
print('Decision: Reject Ho')
# Out:
# array([[12, 22,  9],
#        [32, 14,  6]])
# array([[19.91578947, 16.29473684,  6.78947368],
#        [24.08421053, 19.70526316,  8.21052632]])
# Test Statistic: 10.712198008709638
# p-value: 0.004719280137040844
# Degrees of Freedom: 2
#
#
# Ho: There is a relationsip between height and leadership qualities
#
# Ha: There is no relationsip between height and leadership qualities
#
# α = 0.01
# Decision: Reject Ho

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)

# %%
Married = [679, 63, 42]
W_D_S = [103, 10, 18] #W_D_S = widowed, divorced or seperated
NeverMarried =[114, 20, 25]
Observed_values = np.array([Married, W_D_S, NeverMarried]);display(Observed_values)

chi2, p, ddof, Expected_values = stats.chi2_contingency(Observed_values); display(Expected_values)

test_statistic = "Test Statistic: {}\np-value: {}\nDegrees of Freedom: {}\n"
print(test_statistic.format(chi2, p, ddof))

print('\nHo: Men of different marital status have different distributions of labor force status')
print('\nHa: Men of different marital status dont have different distributions of labor force status')
print('\nα = 0.05')
print('Decision: Reject Ho')
# Out:
# array([[679,  63,  42],
#        [103,  10,  18],
#        [114,  20,  25]])
# array([[654.06331471,  67.88826816,  62.04841713],
#        [109.2886406 ,  11.34357542,  10.36778399],
#        [132.64804469,  13.76815642,  12.58379888]])
# Test Statistic: 31.61310319407798
# p-value: 2.2949883042859918e-06
# Degrees of Freedom: 4
#
#
# Ho: Men of different marital status have different distributions of labor force status
#
# Ha: Men of different marital status dont have different distributions of labor force status
#
# α = 0.05
# Decision: Reject Ho
